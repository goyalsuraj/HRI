# %% [markdown]
# **Due date is 11/27/19 at midnight**
#
# The assignment has to be done individually and Oakland University's policy for academic code of conduct applies.

# %% [markdown]
# **The goal of the assignment is to:**
# * Implement feature matching for problem1 to get more familiarity with opencv and be able to use similar image processing techniques in the future.
# * Build a basic feed forward neural network for problem2 which will help you create more intricate neural networks.
#
# * Note please upload the image you select for problem 1.2

# %% [markdown]
# **Problem 1**
# * Feature matching using opencv ORB (Oriented FAST and Rotated BRIEF)
# * If the matching procedure returns a high score, then there is a high probability that the two objects are similar.
#
#
#
# Reference: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_feature2d/py_orb/py_orb.html#orb

# %% [markdown]
# **Problem 1.1**
# 1. Upload the nyc.jpg and nyc1.jpg
# 2. Find keypoint features in the images by using ORB and compute descriptors.
# 3. draw the keypoints (check the reference) and display both the images
# 4. Match the keypoint features by drawing lines between the image keypoints identified.
# 5. Display your final output
# 6. Comment on your results.

# %%
# Upload and read the image 
# Code here

# %%
# Find the keypoints and descriptors with ORB
# Draw the keypoints

# %%
# Display the Images

# %%
# Match the images for keypoint features



# display your final output

# %% [markdown]
# * Comment on your results below

# %% [markdown]
# **Problem 1.2**
# 1. Take an image of an animal face or a human face
# 2. Find keypoint features in the image by using ORB and compute descriptors.
# 3. Rotate the original image by 45 degrees and convert it to gray scale
# 4. draw the keypoints (check the reference) and display both the images
# 5. Match the keypoint features by drawing lines in between the original and the modified image for the detected keypoints.
# 6. Display your final output
# 7. Comment on your results.

# %%
#Code here

# %% [markdown]
# **Problem 2**
#
# * Build a neural network
#
# * Based on the pipeline below take 6 random values as inputs and pass it through a neural network with 2 input neurons, 3 hidden neurons and 2 output neurons.
#
# * Follow the pipeline below which will guide you through each step.

# %%
#importing numpy library
import numpy as np

# %% [markdown]
# * Define input X for the input layer
#
# * Print out the shape of the input which should match the expected output shown below.

# %%
# Hint use np.array with 6 values such as [0,1,0,1,0,1]
# Add your code below
X = None

# %% [markdown]
# Expected Output (3,2)

# %% [markdown]
# * Weights based on the input layer, hidden layer, output layer

# %%
#Add the layer sizes below

INPUT_LAYER_SIZE = None
HIDDEN_LAYER_SIZE = None
OUTPUT_LAYER_SIZE = None

# Weights W1 and W2 for the hidden layer and the output layer
#Hint use np.random to generate random weight values
#Add your code below...
W1 = np.random.randn(INPUT_LAYER_SIZE, HIDDEN_LAYER_SIZE) 
W2 = None

# %% [markdown]
# * bias based on the hidden layer and the output layer

# %%
#Bias B1 and B2 as .05 value for the hidden layer and the output layer
#Hint use np.full
#Add your code below
B1 = np.full((1, HIDDEN_LAYER_SIZE), 0.05)
B2 = None

# %% [markdown]
# * Show below the size for the weight and bias matrix

# %%
#Print shape for weights and bias
#Shape is a great way to check if you are using the correct dimensions

# %% [markdown]
# * Expected weight shapes are (2,3) and (3,2); bias shapes are (1,3) and (1,2)

# %% [markdown]
# * Activation Function to add non-linearity. It is going to be RELU in this case. You are welcome to try other activation functions.
#
# * Rectified Linear Unit returns 0 if it receives any negative input, but for any positive value  x  it returns that value back. f(x)=max(0,x) .

# %%
def relu(Z):
  
  """Add your code to modify
  the ReLU function below"""
  
  return Z

# %% [markdown]
# #Hidden Layer

# %%
"""" Calculate the output for the hidden layer
     .......using the inputs, weights and bias
->Hint use np.dot
Add your code below
""""
Z1 = None

#Call the relu function to calculate activation for the hidden layer
A = None

# %% [markdown]
# #Output Layer
# Calculate the output y using the inputs, weights and bias
#
# ->Hint use np.dot for the dot product between inputs and weight
#
# Add your code below

# %%
# Use the output from the Hidden Layer as an input
Z2 = None

# Final activation for the output layer
yHat = None

# %% [markdown]
# **Print your final output**
